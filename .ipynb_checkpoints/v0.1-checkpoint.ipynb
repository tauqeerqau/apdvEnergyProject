# %%
import pandas as pd

# Load CSV (skip metadata rows)
df_raw = pd.read_csv(
    "renewable_electricity.csv",
    skiprows=4
)

print(df_raw.shape)
df_raw.head()

# %%
# World Bank year columns are numeric strings
year_cols = [col for col in df_raw.columns if col.isdigit()]

print(year_cols[:5], "...", year_cols[-5:])

# %%
df_transformed = df_raw.melt(
    id_vars=["Country Name", "Country Code"],
    value_vars=year_cols,
    var_name="year",
    value_name="renewable_electricity_percent"
)

df_transformed.head()

# %%
df_transformed = df_transformed.dropna().copy()
df_transformed["year"] = df_transformed["year"].astype(int)

df_transformed.info()

# %%
df_transformed.to_csv(
    "renewable_electricity_processed.csv",
    index=False
)

print("New transformed CSV created successfully")

# %%
import pandas as pd

df_processed = pd.read_csv("renewable_electricity_processed.csv")

df_processed.head()

# %%
import sqlite3

conn = sqlite3.connect("electricity.db")
print("Connected to SQLite")

# %%
df_processed.to_sql(
    "renewable_electricity",
    conn,
    if_exists="replace",
    index=False
)

print("Processed CSV loaded into SQLite successfully")

# %%
query = "SELECT * FROM renewable_electricity LIMIT 5"
pd.read_sql(query, conn)

# %%
conn.close()
print("SQLite connection closed")

# %%
import requests

url = "https://api.worldbank.org/v2/country/all/indicator/EG.USE.ELEC.KH.PC?format=json&per_page=20000"

response = requests.get(url)
json_data = response.json()

type(json_data)
# Out:
# list

# %%
import pandas as pd

records = []

for item in json_data[1]:
    records.append({
        "country_name": item["country"]["value"],
        "country_code": item["country"]["id"],
        "year": item["date"],
        "electricity_use_kwh_per_capita": item["value"]
    })

df_json = pd.DataFrame(records)

df_json.head()
# Out:
#                   country_name country_code  year  \
# 0  Africa Eastern and Southern           ZH  2024
# 1  Africa Eastern and Southern           ZH  2023
# 2  Africa Eastern and Southern           ZH  2022
# 3  Africa Eastern and Southern           ZH  2021
# 4  Africa Eastern and Southern           ZH  2020
#
#    electricity_use_kwh_per_capita
# 0                             NaN
# 1                             NaN
# 2                      501.466616
# 3                      514.341833
# 4                      512.766661

# %%
df_json = df_json.dropna().copy()
df_json["year"] = df_json["year"].astype(int)

df_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6412 entries, 2 to 17259
# Data columns (total 4 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   country_name                    6412 non-null   object
#  1   country_code                    6412 non-null   object
#  2   year                            6412 non-null   int64
#  3   electricity_use_kwh_per_capita  6412 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 250.5+ KB

# %%
import pymongo
from pymongo import MongoClient

# Connect to local MongoDB
client = MongoClient("mongodb+srv://taqApdvAdmin:T%40uq33r7861@electricitydatabase.rodgmrs.mongodb.net/?appName=electricityDatabase")

# Create / use database
db = client["electricity_db"]

print("Connected to MongoDB")
# Out:
# Connected to MongoDB

# %%
collection = db["electricity_use_per_capita"]

print("Collection selected")
# Out:
# Collection selected

# %%
records = df_json.to_dict(orient="records")

len(records), records[0]
# Out:
# (6412,
#  {'country_name': 'Africa Eastern and Southern',
#   'country_code': 'ZH',
#   'year': 2022,
#   'electricity_use_kwh_per_capita': 501.466615909756})

# %%
collection.delete_many({})
print("Old records removed (if any)")
# Out:
# Old records removed (if any)

# %%
result = collection.insert_many(records)

print(f"Inserted {len(result.inserted_ids)} documents into MongoDB")
# Out:
# Inserted 6412 documents into MongoDB

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('693d5db9349a06ef23343a9d'),
#  'country_name': 'Africa Eastern and Southern',
#  'country_code': 'ZH',
#  'year': 2022,
#  'electricity_use_kwh_per_capita': 501.466615909756}

# %%
import requests
import pandas as pd

url = "https://api.worldbank.org/v2/country/all/indicator/EG.USE.ELEC.KH.PC?format=json&per_page=20000"

response = requests.get(url)
data = response.json()[1]

rows = []

for item in data:
    rows.append({
        "country_name": item["country"]["value"],
        "country_code": item["country"]["id"],
        "year": int(item["date"]),
        "electricity_use_kwh_per_capita": item["value"]
    })

df_xml_equivalent = pd.DataFrame(rows).dropna()

print("Rows:", len(df_xml_equivalent))
df_xml_equivalent.head()
# Out:
# Rows: 6412
#                   country_name country_code  year  \
# 2  Africa Eastern and Southern           ZH  2022
# 3  Africa Eastern and Southern           ZH  2021
# 4  Africa Eastern and Southern           ZH  2020
# 5  Africa Eastern and Southern           ZH  2019
# 6  Africa Eastern and Southern           ZH  2018
#
#    electricity_use_kwh_per_capita
# 2                      501.466616
# 3                      514.341833
# 4                      512.766661
# 5                      548.496602
# 6                      568.141299

# %%
df_xml_equivalent.to_csv(
    "electricity_use_per_capita_xml_processed.csv",
    index=False
)

print("XML-equivalent CSV written successfully")
# Out:
# XML-equivalent CSV written successfully

# %%
import sqlite3

conn = sqlite3.connect("electricity.db")

df_xml_equivalent.to_sql(
    "electricity_use_per_capita",
    conn,
    if_exists="replace",
    index=False
)

conn.close()

print("XML-equivalent data inserted into SQLite")
# Out:
# XML-equivalent data inserted into SQLite

# %%
conn = sqlite3.connect("electricity.db")
pd.read_sql("SELECT COUNT(*) AS total FROM electricity_use_per_capita", conn)
# Out:
#    total
# 0   6412

# %%
client = MongoClient("mongodb+srv://taqApdvAdmin:T%40uq33r7861@electricitydatabase.rodgmrs.mongodb.net/?appName=electricityDatabase")
db = client["electricity_db"]

collection = db["electricity_use_per_capita"]

mongo_data = list(collection.find({}, {"_id": 0}))
df_mongo = pd.DataFrame(mongo_data)

df_mongo.head(), df_mongo.shape
# Out:
# (                  country_name country_code  year  \
#  0  Africa Eastern and Southern           ZH  2022
#  1  Africa Eastern and Southern           ZH  2021
#  2  Africa Eastern and Southern           ZH  2020
#  3  Africa Eastern and Southern           ZH  2019
#  4  Africa Eastern and Southern           ZH  2018
#
#     electricity_use_kwh_per_capita
#  0                      501.466616
#  1                      514.341833
#  2                      512.766661
#  3                      548.496602
#  4                      568.141299  ,
#  (6412, 4))

# %%
import sqlite3
import pandas as pd
from pymongo import MongoClient
import pycountry

# %%
def iso2_to_iso3(code):
    try:
        return pycountry.countries.get(alpha_2=code).alpha_3
    except:
        return None

def is_valid_iso3(code):
    try:
        return pycountry.countries.get(alpha_3=code) is not None
    except:
        return False

# %%
conn = sqlite3.connect("electricity.db")

# %%
df_renewable = pd.read_sql(
    """
    SELECT
        "Country Code" AS country_code,
        year,
        renewable_electricity_percent
    FROM renewable_electricity
    """,
    conn
)

# %%
df_use_sqlite = pd.read_sql(
    """
    SELECT
        country_code,
        year,
        electricity_use_kwh_per_capita
    FROM electricity_use_per_capita
    """,
    conn
)

conn.close()

# %%
df_renewable = df_renewable[
    df_renewable["country_code"].apply(is_valid_iso3)
].copy()

df_use_sqlite = df_use_sqlite[
    df_use_sqlite["country_code"].apply(is_valid_iso3)
].copy()

# %%
for df in [df_renewable, df_use_sqlite]:
    df["country_code"] = df["country_code"].astype(str)
    df["year"] = df["year"].astype(int)

# %%
df_sqlite_integrated = pd.merge(
    df_renewable,
    df_use_sqlite,
    on=["country_code", "year"],
    how="left"
)

df_sqlite_integrated.shape
# Out:
# (5777, 4)

# %%
client = MongoClient("mongodb+srv://taqApdvAdmin:T%40uq33r7861@electricitydatabase.rodgmrs.mongodb.net/?appName=electricityDatabase")
db = client["electricity_db"]

collection = db["electricity_use_per_capita"]
mongo_data = list(collection.find({}, {"_id": 0}))

df_mongo = pd.DataFrame(mongo_data)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[123], line 5
#       2 db = client["electricity_db"]
#       4 collection = db["electricity_use_per_capita"]
# ----> 5 mongo_data = list(collection.find({}, {"_id": 0}))
#       7 df_mongo = pd.DataFrame(mongo_data)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\cursor.py:1289, in Cursor.__next__(self)
#    1288 def __next__(self) -> _DocumentType:
# -> 1289     return self.next()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\cursor.py:1265, in Cursor.next(self)
#    1263 if self._empty:
#    1264     raise StopIteration
# -> 1265 if len(self._data) or self._refresh():
#    1266     return self._data.popleft()
#    1267 else:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\cursor.py:1213, in Cursor._refresh(self)
#    1191         raise InvalidOperation(
#    1192             "Passing a 'hint' is required when using the min/max query"
#    1193             " option to ensure the query utilizes the correct index"
#    1194         )
#    1195     q = self._query_class(
#    1196         self._query_flags,
#    1197         self._collection.database.name,
#    (...)   1211         self._exhaust,
#    1212     )
# -> 1213     self._send_message(q)
#    1214 elif self._id:  # Get More
#    1215     if self._limit:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\cursor.py:1108, in Cursor._send_message(self, operation)
#    1105     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1107 try:
# -> 1108     response = client._run_operation(
#    1109         operation, self._unpack_response, address=self._address
#    1110     )
#    1111 except OperationFailure as exc:
#    1112     if exc.code in _CURSOR_CLOSED_ERRORS or self._exhaust:
#    1113         # Don't send killCursors because the cursor is already closed.
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\mongo_client.py:1938, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1928     operation.reset()  # Reset op in case of retry.
#    1929     return server.run_operation(
#    1930         conn,
#    1931         operation,
#    (...)   1935         self,
#    1936     )
# -> 1938 return self._retryable_read(
#    1939     _cmd,
#    1940     operation.read_preference,
#    1941     operation.session,  # type: ignore[arg-type]
#    1942     address=address,
#    1943     retryable=isinstance(operation, _Query),
#    1944     operation=operation.name,
#    1945 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\mongo_client.py:2047, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2042 # Ensure that the client supports retrying on reads and there is no session in
#    2043 # transaction, otherwise, we will not support retry behavior for this call.
#    2044 retryable = bool(
#    2045     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2046 )
# -> 2047 return self._retry_internal(
#    2048     func,
#    2049     session,
#    2050     None,
#    2051     operation,
#    2052     is_read=True,
#    2053     address=address,
#    2054     read_pref=read_pref,
#    2055     retryable=retryable,
#    2056     operation_id=operation_id,
#    2057 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)   1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)   2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\mongo_client.py:2765, in _ClientConnectionRetryable.run(self)
#    2763 self._check_last_error(check_csot=True)
#    2764 try:
# -> 2765     return self._read() if self._is_read else self._write()
#    2766 except ServerSelectionTimeoutError:
#    2767     # The application may think the write was never attempted
#    2768     # if we raise ServerSelectionTimeoutError on the retry
#    2769     # attempt. Raise the original exception instead.
#    2770     self._check_last_error()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\mongo_client.py:2910, in _ClientConnectionRetryable._read(self)
#    2905 def _read(self) -> T:
#    2906     """Wrapper method for read-type retryable client executions
#    2907
#    2908     :return: Output for func()'s call
#    2909     """
# -> 2910     self._server = self._get_server()
#    2911     assert self._read_pref is not None, "Read Preference required on read calls"
#    2912     with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2913         conn,
#    2914         read_pref,
#    2915     ):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\mongo_client.py:2858, in _ClientConnectionRetryable._get_server(self)
#    2853 def _get_server(self) -> Server:
#    2854     """Retrieves a server object based on provided object context
#    2855
#    2856     :return: Abstraction to connect to server
#    2857     """
# -> 2858     return self._client._select_server(
#    2859         self._server_selector,
#    2860         self._session,
#    2861         self._operation,
#    2862         address=self._address,
#    2863         deprioritized_servers=self._deprioritized_servers,
#    2864         operation_id=self._operation_id,
#    2865     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\mongo_client.py:1833, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1831             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1832     else:
# -> 1833         server = topology.select_server(
#    1834             server_selector,
#    1835             operation,
#    1836             deprioritized_servers=deprioritized_servers,
#    1837             operation_id=operation_id,
#    1838         )
#    1839     return server
#    1840 except PyMongoError as exc:
#    1841     # Server selection errors in a transaction are transient.
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\topology.py:409, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     399 def select_server(
#     400     self,
#     401     selector: Callable[[Selection], Selection],
#    (...)    406     operation_id: Optional[int] = None,
#     407 ) -> Server:
#     408     """Like select_servers, but choose a random server if several match."""
# --> 409     server = self._select_server(
#     410         selector,
#     411         operation,
#     412         server_selection_timeout,
#     413         address,
#     414         deprioritized_servers,
#     415         operation_id=operation_id,
#     416     )
#     417     if _csot.get_timeout():
#     418         _csot.set_rtt(server.description.min_round_trip_time)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\topology.py:387, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     378 def _select_server(
#     379     self,
#     380     selector: Callable[[Selection], Selection],
#    (...)    385     operation_id: Optional[int] = None,
#     386 ) -> Server:
# --> 387     servers = self.select_servers(
#     388         selector, operation, server_selection_timeout, address, operation_id
#     389     )
#     390     servers = _filter_servers(servers, deprioritized_servers)
#     391     if len(servers) == 1:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\topology.py:294, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id)
#     291     self.cleanup_monitors()
#     293 with self._lock:
# --> 294     server_descriptions = self._select_servers_loop(
#     295         selector, server_timeout, operation, operation_id, address
#     296     )
#     298     return [
#     299         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     300     ]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\topology.py:344, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address)
#     333     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     334         _debug_log(
#     335             _SERVER_SELECTION_LOGGER,
#     336             message=_ServerSelectionStatusMessage.FAILED,
#    (...)    342             failure=self._error_message(selector),
#     343         )
# --> 344     raise ServerSelectionTimeoutError(
#     345         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     346     )
#     348 if not logged_waiting:
#     349     _debug_log(
#     350         _SERVER_SELECTION_LOGGER,
#     351         message=_ServerSelectionStatusMessage.WAITING,
#    (...)    357         remainingTimeMS=int(1000 * (end_time - time.monotonic())),
#     358     )
#
# ServerSelectionTimeoutError: localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 693d7953349a06ef233453ac, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [WinError 10061] No connection could be made because the target machine actively refused it (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
df_mongo = df_mongo.dropna().copy()
df_mongo["year"] = df_mongo["year"].astype(int)

# Convert ISO-2 → ISO-3
df_mongo["country_code_iso3"] = df_mongo["country_code"].apply(iso2_to_iso3)

# Keep real countries only
df_mongo = df_mongo.dropna(subset=["country_code_iso3"])

# %%
df_mongo_country = (
    df_mongo
    .groupby("country_code_iso3", as_index=False)
    .agg({
        "electricity_use_kwh_per_capita": "mean"
    })
)

df_mongo_country.shape
